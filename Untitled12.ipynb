# %% [markdown]
# <a href="https://colab.research.google.com/github/LERDLC/LERDLC/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv("https://raw.githubusercontent.com/robintux/Datasets4StackOverFlowQuestions/master/cardiotocograms_2000.csv")
dataset
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# 4              132.0          0.007           0.000                 0.008
# ...              ...            ...             ...                   ...
# 2121           140.0          0.000           0.000                 0.007
# 2122           140.0          0.001           0.000                 0.007
# 2123           140.0          0.001           0.000                 0.007
# 2124           140.0          0.001           0.000                 0.006
# 2125           142.0          0.002           0.002                 0.008
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
X=dataset.iloc[:,0:21]
y=dataset.iloc[:,21]

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import rmsprop_v2
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
def create_network(optimizer='adam', learning_rate=0.001, penalty = ['l1', 'l2'], solver= ['newton-cg', 'lbfgs', 'liblinear'], C= [1, 2, 5, 10, 20]):
    
    # Start Artificial Neural Network
    network = Sequential()


    network.add(Dense(input_dim =21 , units = 18, activation = "relu",
                     name = "1eraCapaOculta_45Neuronas") )
    # 
    # Agreguemos otra capa oculta : neuronas = 27
    network.add(Dense(units = 27, activation = "sigmoid", 
                     name = "2daCapaOculta_7Neuronas"))
    # 
    # Agreguemos una 3era capa oculta con 20 neuronasl 
    network.add(Dense(units = 20, activation = "exponential",
                     name = "3eraCapaOculta_12Nueronas"))
    
    #Agreguemos una 5ta capa oculta con 35 neuronasl 
    network.add(Dense(units = 35, activation = "sigmoid",
                    name = "5taCapaOculta_35Nueronas"))
  
    
    network.add(Dense(1,activation = "elu",
                     name ="Capa_de_SAlida"))

    ###############################################
    # Add optimizer with learning rate
    if optimizer == 'rmsprop':
        opt = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
    elif optimizer == 'adam':
        opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == 'SGD':
        opt = tf.keras.optimizers.SGD(learning_rate=learning_rate)
    else:
        raise ValueError('optimizer {} unrecognized'.format(optimizer))
    ##############################################    

    # Compile NN
    network.compile(optimizer = opt, 
                loss = 'mean_squared_error', 
                metrics=['mae', tf.keras.metrics.RootMeanSquaredError()])
    
    # Return compiled network
    return network

# Wrap Keras model so it can be used by scikit-learn
ann = KerasRegressor(build_fn=create_network, verbose=0)


# Create hyperparameter space

epoch_values = [10, 25, 50, 100, 150, 200]
batches = [10, 20, 30, 40, 50, 100, 1000]
optimizers = ['adam']
penalty_values = ['l1', 'l2']
solver_list= ['newton-cg', 'lbfgs', 'liblinear']
C_values= [1, 2, 5, 10, 20]

# Create hyperparameter options
hyperparameters = dict(
    epochs=epoch_values, 
    batch_size=batches, 
    optimizer=optimizers,
    penalty=penalty_values,
    solver= solver_list,
    C=C_values)

# Create grid search
# cv=5 is the default 5-fold
grid = GridSearchCV(estimator=ann, cv=5, param_grid=hyperparameters)

# Fit grid search
grid_result = grid.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-2e6877f3d9ef> in <module>
#      71
#      72 # Fit grid search
# ---> 73 grid_result = grid.fit(X, y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
# ...

# %%
#%%Grid
from keras.optimizers import *
def create_model(learning_date = 0.01, momentum = 0):
    model1 = Sequential()
    model1.add(Dense(input_dim =21 , units = 18, activation = "relu",
                     name = "1eraCapaOculta_45Neuronas") )
    # 
    # Agreguemos otra capa oculta : neuronas = 27
    model1.add(Dense(units = 27, activation = "sigmoid", 
                     name = "2daCapaOculta_7Neuronas"))
    # 
    # Agreguemos una 3era capa oculta con 20 neuronasl 
    model1.add(Dense(units = 20, activation = "exponential",
                     name = "3eraCapaOculta_12Nueronas"))
    
    #Agreguemos una 5ta capa oculta con 35 neuronasl 
    model1.add(Dense(units = 35, activation = "sigmoid",
                    name = "5taCapaOculta_35Nueronas"))
  
    
    model1.add(Dense(1,activation = "elu",
                     name ="Capa_de_SAlida"))
    
    model1.compile(loss = "mean_squared_error",
                   optimizer = "SGD",
                   metrics = "MeanAbsoluteError"        
                   )

    return model1
#Creamos nuestro modelo para realizar el gridsearch (sklearn)

# %%
modReg_1 = KerasRegressor(build_fn = create_model)
param_grid_2 = {'penalty': ['l1', 'l2'], 'solver': ('newton-cg', 'lbfgs', 'liblinear'),'C': [1, 2, 5, 10, 20]}
GridReg1 = GridSearchCV(estimator = modReg_1, param_grid = param_grid_2,
                           cv = 5,
                           verbose = 4,
                           n_jobs = 4)
ResultadosReg1 = GridReg1.fit(X,y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-6c8a16cce8c8> in <module>
#       5                            verbose = 4,
#       6                            n_jobs = 4)
# ----> 7 ResultadosReg1 = GridReg1.fit(X,y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
# ...
